# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use ('classic')
imagen = Image.open ("../imagenes/cocodrilo,descarga (8).jpg")

plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=225x225 at 0x24AA5B28C90>

# %%
imagen_mat = np.array (list(imagen_gr.getdata(band=0)),float)
print(imagen_mat)
imagen_mat.shape =(imagen_gr.size[1],imagen_gr.size[0])
print(imagen_mat.shape)
# Out:
# [1. 1. 1. ... 2. 2. 2.]
# (225, 225)

# %%
U,D,V = np.linalg.svd (imagen_mat)

# %%
print(imagen_mat.shape)
print(U.shape)
print(D.shape)
print(V.shape)
# Out:
# (225, 225)
# (225, 225)
# (225,)
# (225, 225)

# %%
imagen_recons = np.matrix (U[:,:1])*np.diag(D[:1])*np.matrix(V[:1,:])
plt.imshow(imagen_recons,cmap='gray')

# %%
imagen_gr = imagen.convert('LA')
imagen_A = np.array(list(imagen_gr.getdata(band=1)),float)
imagen_A.shape = (imagen_gr.size[1], imagen_gr.size[0])
plt.imshow(imagen_A)

# %%
i = 5
imagen_recons = np.matrix (U[:,:i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons,cmap='gray')

titulo= "valores singulares = %s" %i

plt.title (titulo)
# Out:
# Text(0.5, 1.0, 'valores singulares = 5')

# %%
i = 15
imagen_recons = np.matrix (U[:,:i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons,cmap='gray')

titulo= "valores singulares = %s" %i

plt.title (titulo)
# Out:
# Text(0.5, 1.0, 'valores singulares = 15')

# %%
i = 25
imagen_recons = np.matrix (U[:,:i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons,cmap='gray')

titulo= "valores singulares = %s" %i

plt.title (titulo)
# Out:
# Text(0.5, 1.0, 'valores singulares = 25')

# %%
i = 500
imagen_recons = np.matrix (U[:,:i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons,cmap='gray')

titulo= "valores singulares = %s" %i

plt.title (titulo)
# Out:
# Text(0.5, 1.0, 'valores singulares = 500')

# %%
from IPython.display import clear_output

plt.figure()
for n in range(101):
    plt.imshow(U[:,:n]@np.diag(D[:n])@V[:n,:], cmap='gray')
    plt.title(f"SV's = {n}")
    plt.show()
    clear_output(wait=True)
