# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5,5,2)

# %%
print (X)
# Out:
# [-5 -3 -1  1  3]

# %%
Y_1 = 3*x + 5
Y_2 = 2*x + 3

# %%
plt.figure()

plt.plot(X,Y_1)
plt.plot(X, Y_2)


plt.xlim(-5,5)
plt.ylim(-5,5)

plt.axvline(x=0, color= 'grey' )
plt.axhline(y=0, color= 'grey' )
